# %% [markdown]
#  ## ![image.png](attachment:image.png)

# %% [markdown]
#     Recommender system can be classified into 2:
#         1. THE PREDICTION PROBLEM
#         2. THE RANKING PROBLEM

# %% [markdown]
# - The prediction problem aims to predict missing values usig all information it has at its disposal(the rating recorded,data on movies,data on users and so on).
# - If it will be able to predict this values accurately it can give better recommendations

# %% [markdown]
# # TYPES OF RECOMMENDATION SYSTEMS

# %% [markdown]
#     Based data requirement we are listing major recommendation systems.
#     1- COLLABORATIVE FILTERING
#     2- CONTENT BASED SYSTEMS
#     3- KNOWLEDGE BASED RECOMMENDERS
#     4- HYBRID RECOMMENDERS

# %% [markdown]
# # Collaborative filtering

# %% [markdown]
# - most used recommendation system

# %% [markdown]
# Two types of collaborative filtering techniques are used:
#
#    **-User collaborative filtering**
#
#    **-Item collaborative filtering**

# %% [markdown]
# ### USER BASED FILTERING

# %% [markdown]
# Main idea behind user based filtering is that if we are able to find users that have bought or likes similar items in the past,they are more likely to buy similar items ibn the future too.
#
# Examples: Amazon,flipkart,netflix

# %% [markdown]
# ## ![image.png](attachment:image.png)

# %% [markdown]
# ### ITEM BASED FILTERING

# %% [markdown]
# - Recently viewed items and featured recommendations
# - Inspired by our past history

# %% [markdown]
# ## ![image.png](attachment:image.png)

# %% [markdown]
# ##### Advantages
# - New products can be introduced to the user.
# - Business can be expanded and can popularise new products.

# %% [markdown]
# ##### Disadvantages
#
# - Biggest prerequitities of a collaborative system is the availability of data of past activity
# - User’s previous history is required or data for products is required based on the type of collaborative method used.
# - The new item cannot be recommended if no user has purchased or rated it.

# %% [markdown]
# - Hence collaborative filters suffer from what we call the **cold start problem**

# %% [markdown]
# # Content-based filtering

# %% [markdown]
# - Unlike collaborative systems content based recommenders do not require past activity.
# - Recommend based on user profile and metadata it has on particular items.
#
# Examples : Netflix(while sign in ,the app asks about recently watched films to know more about our wish)

# %% [markdown]
# ## ![image.png](attachment:image.png)

# %% [markdown]
# ## ![image.png](attachment:image.png)

# %% [markdown]
# ## ![image.png](attachment:image.png)

# %% [markdown]
# ##### Advantages
#
# - The user gets recommended the types of items they love.
# - The user is satisfied by the type of recommendation.
# - New items can be recommended; just data for that item is required.

# %% [markdown]
# ##### Disadvantages
# - The user will never be recommended for different items.
# - Business cannot be expanded as the user does not try a different type of product.
# - If the user matrix or item matrix is changed the cosine similarity matrix needs to be calculated again.

# %% [markdown]
#  ## ![image.png](attachment:image.png)

# %% [markdown]
# # Knowledge Based Recommender

# %% [markdown]
# Knowledge based recommenders are used for items that are rarely bought.
#
# Example: Things checking before buy a land,trip planning....

# %% [markdown]
# ## ![image.png](attachment:image.png)

# %% [markdown]
# ## ![image.png](attachment:image.png)

# %% [markdown]
# ## ![image.png](attachment:image.png)

# %% [markdown]
# # Hybrid Recommender

# %% [markdown]
# Combination of collaboratory filtering and content based filtering.
#
#  COLLABORATORY FILTERING + CONTENT BASED FILTERING = HYBRID RECOMMENDER

# %% [markdown]
# ## ![image.png](attachment:image.png)

# %% [markdown]
# ## ![image.png](attachment:image.png)

# %% [markdown]
# ## ![image.png](attachment:image.png)
